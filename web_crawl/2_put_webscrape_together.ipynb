# %%
import pandas as pd
import os

def files_to_dataframe(directory):
    all_data = []
    for filename in os.listdir(directory):
        filepath = os.path.join(directory, filename)
        if os.path.isfile(filepath): 
            try:
                df = pd.read_csv(filepath)  
                df['filename'] = filename  
                all_data.append(df)
            except Exception as e:
                print(f"Error reading {filename}: {e}")
    combined_df = pd.concat(all_data, ignore_index=True)
    return combined_df

# %%
# Example usage:
directory_path = 'C:\\programming_projects\\ASU\\web_crawl\\web_data\\'
df = files_to_dataframe(directory_path)
print(df)
# Out:
# Error reading webpage_analysis_run_11120.csv: No columns to parse from file
# Error reading webpage_analysis_run_1164.csv: No columns to parse from file
# Error reading webpage_analysis_run_1166.csv: No columns to parse from file
# Error reading webpage_analysis_run_1168.csv: No columns to parse from file
# Error reading webpage_analysis_run_1170.csv: No columns to parse from file
# Error reading webpage_analysis_run_1172.csv: No columns to parse from file
# Error reading webpage_analysis_run_1174.csv: No columns to parse from file
# Error reading webpage_analysis_run_1176.csv: No columns to parse from file
# Error reading webpage_analysis_run_1178.csv: No columns to parse from file
# Error reading webpage_analysis_run_1410.csv: No columns to parse from file
# Error reading webpage_analysis_run_1432.csv: No columns to parse from file
# Error reading webpage_analysis_run_1434.csv: No columns to parse from file
# Error reading webpage_analysis_run_1436.csv: No columns to parse from file
# Error reading webpage_analysis_run_1438.csv: No columns to parse from file
# Error reading webpage_analysis_run_1440.csv: No columns to parse from file
# Error reading webpage_analysis_run_1442.csv: No columns to parse from file
# Error reading webpage_analysis_run_1444.csv: No columns to parse from file
# Error reading webpage_analysis_run_1446.csv: No columns to parse from file
# Error reading webpage_analysis_run_1448.csv: No columns to parse from file
# Error reading webpage_analysis_run_1450.csv: No columns to parse from file
# Error reading webpage_analysis_run_1454.csv: No columns to parse from file
# Error reading webpage_analysis_run_1456.csv: No columns to parse from file
# Error reading webpage_analysis_run_16340.csv: No columns to parse from file
# Error reading webpage_analysis_run_16360.csv: No columns to parse from file
# Error reading webpage_analysis_run_16380.csv: No columns to parse from file
# Error reading webpage_analysis_run_1952.csv: No columns to parse from file
# Error reading webpage_analysis_run_2204.csv: No columns to parse from file
# Error reading webpage_analysis_run_2208.csv: No columns to parse from file
# Error reading webpage_analysis_run_2296.csv: No columns to parse from file
# Error reading webpage_analysis_run_2364.csv: No columns to parse from file
# Error reading webpage_analysis_run_23940.csv: No columns to parse from file
# Error reading webpage_analysis_run_23960.csv: No columns to parse from file
# Error reading webpage_analysis_run_264.csv: No columns to parse from file
# Error reading webpage_analysis_run_266.csv: No columns to parse from file
# Error reading webpage_analysis_run_2704.csv: No columns to parse from file
# Error reading webpage_analysis_run_2706.csv: No columns to parse from file
# Error reading webpage_analysis_run_272.csv: No columns to parse from file
# Error reading webpage_analysis_run_28200.csv: No columns to parse from file
# Error reading webpage_analysis_run_2876.csv: No columns to parse from file
# Error reading webpage_analysis_run_2880.csv: No columns to parse from file
# Error reading webpage_analysis_run_2906.csv: No columns to parse from file
# Error reading webpage_analysis_run_29360.csv: No columns to parse from file
# Error reading webpage_analysis_run_29380.csv: No columns to parse from file
# Error reading webpage_analysis_run_29400.csv: No columns to parse from file
# Error reading webpage_analysis_run_29420.csv: No columns to parse from file
# Error reading webpage_analysis_run_29440.csv: No columns to parse from file
# Error reading webpage_analysis_run_806.csv: No columns to parse from file
# Error reading webpage_analysis_run_856.csv: No columns to parse from file
# Error reading webpage_analysis_run_862.csv: No columns to parse from file
# Error reading webpage_analysis_run_864.csv: No columns to parse from file
# Error reading webpage_analysis_run_866.csv: No columns to parse from file
# Error reading webpage_analysis_run_8760.csv: No columns to parse from file
# Error reading webpage_analysis_run_880.csv: No columns to parse from file
# Error reading webpage_analysis_run_888.csv: No columns to parse from file
# Error reading webpage_analysis_run_892.csv: No columns to parse from file
# Error reading webpage_analysis_run_894.csv: No columns to parse from file
# Error reading webpage_analysis_run_964.csv: No columns to parse from file
#                                                      url  depth  \
# 0          https://admission.asu.edu/undergrad/nondegree      1
# 1        https://asuonline.asu.edu/admission/first-year/      1
# 2      https://admission.asu.edu/apply/graduate/admis...      2
# 3            https://admission.asu.edu/cost-aid/graduate      2
# 4                              https://eoss.asu.edu/cora      3
# ...                                                  ...    ...
# 37903  http://graduation.asu.edu/ceremonies/inclement...      4
# 37904      http://graduation.asu.edu/ceremonies/memories      4
# 37905   http://graduation.asu.edu/ceremonies/futuredates      4
# 37906  https://news.asu.edu/interests/entrepreneurshi...      3
# 37907  https://news.asu.edu/20250131-sun-devil-commun...      3
#
#                                                    title  \
# 0                    Nondegree student | Admission | ASU
# 1                       First-Year Students | ASU Online
# 2           Graduate student admission | Admission | ASU
# 3             Graduate student tuition | Admission | ASU
# 4      Council of Religious Advisors | Educational Ou...
# ...                                                  ...
# 37903  Inclement Weather Plan - Mountain America Stad...
# 37904  Regalia, photos, t-shirts and flowers | Gradua...
# 37905       Future dates and Where to watch | Graduation
# 37906                        Entrepreneurship | ASU News
# 37907  A lifetime of experiences prepared Jamea Jacks...
#
#                                     topic  word_count  char_count  \
# 0        Admissions & Application Process        92.0       552.0
# 1         ASU's Global & Online Education        53.0       329.0
# 2        Admissions & Application Process       264.0      1769.0
# 3                   Housing & Campus Life        58.0       404.0
# 4        Student Life & Campus Activities       369.0      2525.0
# ...                                   ...         ...         ...
# 37903                                 NaN         NaN         NaN
# 37904                                 NaN         NaN         NaN
# 37905                                 NaN         NaN         NaN
# 37906         Academic Programs & Courses        11.0        61.0
# 37907  ASU's Commitment to Sustainability      1419.0      8269.0
#
#                                                page_text  \
# 0      Nondegree requirementsTo be eligible to take c...
# 1      ASU Online empowers first-year students to tak...
# 2      In the graduate admission video series below, ...
# 3      Graduate student2025–2026 expensesAs a graduat...
# 4      Celebrate faith, respect diversity, honor spir...
# ...                                                  ...
# 37903  If University Undergraduate Commencement or ot...
# 37904  Caps, Gowns and Graduation Announcements\n\n\n...
# 37905  Future dates\n\n\n\nThe University Academic Ca...
# 37906  ASUNews\nSign up to get the latest stories fro...
# 37907  It was August, 2009. A Tuesday, Jamea Jackson ...
#
#                                    filename
# 0               webpage_analysis_run_10.csv
# 1               webpage_analysis_run_10.csv
# 2              webpage_analysis_run_100.csv
# 3              webpage_analysis_run_100.csv
# 4             webpage_analysis_run_1000.csv
# ...                                     ...
# 37903         webpage_analysis_run_9980.csv
# 37904         webpage_analysis_run_9980.csv
# 37905         webpage_analysis_run_9980.csv
# 37906  webpage_analysis_run_{run_count}.csv
# 37907  webpage_analysis_run_{run_count}.csv
#
# [37908 rows x 8 columns]

# %%
import pandas as pd
import re

def clean_text(text):
  """Keep only alphanumeric characters and basic punctuation."""
  text = re.sub(r'[^a-zA-Z0-9.,!?\s]', ' ', str(text))
  text = re.sub(r'\s+', ' ', text).strip()
  return text


# Apply the function to the DataFrame column
df['cleaned_text'] = df['page_text'].apply(clean_text)

# Remove all whitespace characters (including \r, \n, \t, \f, \v, and spaces)
df['cleaned_text'] = df['cleaned_text'].str.replace(r'\s+', ' ', regex=True).str.strip()

df['title'] = df['title'].apply(clean_text)
df['topic'] = df['topic'].apply(clean_text)
print(df.shape)
# Out:
# (37908, 9)

# %%
df.head()
# Out:
#                                                  url  depth  \
# 0      https://admission.asu.edu/undergrad/nondegree      1
# 1    https://asuonline.asu.edu/admission/first-year/      1
# 2  https://admission.asu.edu/apply/graduate/admis...      2
# 3        https://admission.asu.edu/cost-aid/graduate      2
# 4                          https://eoss.asu.edu/cora      3
#
#                                                title  \
# 0                    Nondegree student Admission ASU
# 1                     First Year Students ASU Online
# 2           Graduate student admission Admission ASU
# 3             Graduate student tuition Admission ASU
# 4  Council of Religious Advisors Educational Outr...
#
#                             topic  word_count  char_count  \
# 0  Admissions Application Process        92.0       552.0
# 1   ASU s Global Online Education        53.0       329.0
# 2  Admissions Application Process       264.0      1769.0
# 3             Housing Campus Life        58.0       404.0
# 4  Student Life Campus Activities       369.0      2525.0
#
#                                            page_text  \
# 0  Nondegree requirementsTo be eligible to take c...
# 1  ASU Online empowers first-year students to tak...
# 2  In the graduate admission video series below, ...
# 3  Graduate student2025–2026 expensesAs a graduat...
# 4  Celebrate faith, respect diversity, honor spir...
#
#                         filename  \
# 0    webpage_analysis_run_10.csv
# 1    webpage_analysis_run_10.csv
# 2   webpage_analysis_run_100.csv
# 3   webpage_analysis_run_100.csv
# 4  webpage_analysis_run_1000.csv
#
#                                         cleaned_text
# 0  Nondegree requirementsTo be eligible to take c...
# 1  ASU Online empowers first year students to tak...
# 2  In the graduate admission video series below, ...
# 3  Graduate student2025 2026 expensesAs a graduat...
# 4  Celebrate faith, respect diversity, honor spir...

# %%
from langdetect import detect, DetectorFactory
DetectorFactory.seed = 0

def lang_detect(text):
  text = re.sub(r'[^a-zA-Z0-9.,!?\s]', '', str(text))
  language_detected = detect(text)
  return language_detected

df['langauage'] = ''
for i in range(0, len(df['langauage'])):
   try:
      df.loc[i,'langauage'] = lang_detect(df['cleaned_text'].iloc[i])
   except:
      print(i, '-', df['cleaned_text'].iloc[i])
# Out:
# 19505 -
# 28499 - .
# 32066 -
# 32081 -
# 32089 -
# 32111 -
# 36358 - , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,
# 36363 - , . , , . 2022 , 40 . , , . , , . , . , , , , , . , . . . , , . , . , . , . 40 . .
# 36366 - , 100 , , , 2022 , 40 , , , , , , , , , , , 100 , , , , , , 40
# 36379 - , 100 , , , 2022 , 40 , , , , , , , , , , , , . 100 , , , , , , 40
# 36396 - 100 2022 40 100 40

# %%
df['word_count'] = df['cleaned_text'].apply(lambda x: len(str(x).split()))

# %%
print(df.shape)
df = df[df['word_count'] > 50]
print(df.shape)
df = df[df['langauage'] == 'en']
print(df.shape)
df_clean = df.drop_duplicates(subset=['title', 'topic', 'word_count', 'char_count', 'cleaned_text', 'langauage'])
print(df_clean.shape)
df_clean.reset_index(drop=True, inplace=True)
# Out:
# (37908, 10)
# (21843, 10)
# (20956, 10)
# (16343, 10)

# %%
df_clean.to_csv('cleaned_ASU_webpage.csv', index=False)

# %%
df_clean.head()
# Out:
#                                                  url  depth  \
# 0      https://admission.asu.edu/undergrad/nondegree      1
# 1    https://asuonline.asu.edu/admission/first-year/      1
# 2  https://admission.asu.edu/apply/graduate/admis...      2
# 3        https://admission.asu.edu/cost-aid/graduate      2
# 4                          https://eoss.asu.edu/cora      3
#
#                                                title  \
# 0                    Nondegree student Admission ASU
# 1                     First Year Students ASU Online
# 2           Graduate student admission Admission ASU
# 3             Graduate student tuition Admission ASU
# 4  Council of Religious Advisors Educational Outr...
#
#                             topic  word_count  char_count  \
# 0  Admissions Application Process          93       552.0
# 1   ASU s Global Online Education          55       329.0
# 2  Admissions Application Process         268      1769.0
# 3             Housing Campus Life          62       404.0
# 4  Student Life Campus Activities         373      2525.0
#
#                                            page_text  \
# 0  Nondegree requirementsTo be eligible to take c...
# 1  ASU Online empowers first-year students to tak...
# 2  In the graduate admission video series below, ...
# 3  Graduate student2025–2026 expensesAs a graduat...
# 4  Celebrate faith, respect diversity, honor spir...
#
#                         filename  \
# 0    webpage_analysis_run_10.csv
# 1    webpage_analysis_run_10.csv
# 2   webpage_analysis_run_100.csv
# 3   webpage_analysis_run_100.csv
# 4  webpage_analysis_run_1000.csv
#
#                                         cleaned_text langauage
# 0  Nondegree requirementsTo be eligible to take c...        en
# 1  ASU Online empowers first year students to tak...        en
# 2  In the graduate admission video series below, ...        en
# 3  Graduate student2025 2026 expensesAs a graduat...        en
# 4  Celebrate faith, respect diversity, honor spir...        en

# %%
df_clean.tail()
# Out:
#                                                      url  depth  \
# 16338                   https://students.asu.edu/diploma      4
# 16339  http://graduation.asu.edu/ceremonies/additiona...      4
# 16340  http://graduation.asu.edu/ceremonies/inclement...      4
# 16341      http://graduation.asu.edu/ceremonies/memories      4
# 16342   http://graduation.asu.edu/ceremonies/futuredates      4
#
#                                                    title topic  word_count  \
# 16338                           Diploma ASU Students ASU   nan         600
# 16339                 Additional Celebrations Graduation   nan         581
# 16340  Inclement Weather Plan Mountain America Stadiu...   nan         210
# 16341   Regalia, photos, t shirts and flowers Graduation   nan         308
# 16342         Future dates and Where to watch Graduation   nan         106
#
#        char_count                                          page_text  \
# 16338         NaN  Diplomas\n\nDiplomas are mailed approximately ...
# 16339         NaN  Arizona State University's commitment to inclu...
# 16340         NaN  If University Undergraduate Commencement or ot...
# 16341         NaN  Caps, Gowns and Graduation Announcements\n\n\n...
# 16342         NaN  Future dates\n\n\n\nThe University Academic Ca...
#
#                             filename  \
# 16338  webpage_analysis_run_9980.csv
# 16339  webpage_analysis_run_9980.csv
# 16340  webpage_analysis_run_9980.csv
# 16341  webpage_analysis_run_9980.csv
# 16342  webpage_analysis_run_9980.csv
#
#                                             cleaned_text langauage
# 16338  Diplomas Diplomas are mailed approximately six...        en
# 16339  Arizona State University s commitment to inclu...        en
# 16340  If University Undergraduate Commencement or ot...        en
# 16341  Caps, Gowns and Graduation Announcements Your ...        en
# 16342  Future dates The University Academic Calendar ...        en
